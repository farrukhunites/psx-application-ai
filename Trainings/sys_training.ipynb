# %%
import tensorflow as tf

# Limit the number of threads TensorFlow will use
config = tf.config.threading.set_intra_op_parallelism_threads(500)  
config = tf.config.threading.set_inter_op_parallelism_threads(500)  

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
from tensorflow.keras.layers import LSTM, Dense, Dropout
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error

# %%
# Load the CSV file
stock='sys'
file_path = stock + '_data.csv'
df = pd.read_csv(file_path)

# Display the first few rows
print(df)
df['Date'] = df['Date'].str.slice(start=9)
df['Date'] = pd.to_datetime(df['Date'])

df.set_index('Date', inplace=True)

plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df['Closing Price'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price PKR (Rs.)', fontsize=18)
plt.grid(True)

plt.show()


data = df.filter(['Closing Price'])
# Convert the dataframe to a numpy array
dataset = data.values
# Get the number of rows to train the model on
training_data_len = int(np.ceil( len(dataset) * .95 ))

print("Training Data Length: ",training_data_len)

# Get the 'Closing Price' column
data = df.filter(['Closing Price'])
dataset = data.values  # Convert the dataframe to a numpy array

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# Set the training data length (95% of the dataset)
training_data_len = int(np.ceil(len(dataset) * .95))

# Split the data into training and testing sets
train_data = scaled_data[0:training_data_len, :]
test_data = scaled_data[training_data_len - 60:, :]  # Include previous 60 time steps for testing

# Prepare the x_train and y_train data
x_train, y_train = [], []

# Create sequences for x_train and corresponding values for y_train
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])  # 60 previous time steps
    y_train.append(train_data[i, 0])  # The next value

# Convert x_train and y_train to numpy arrays
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape x_train to be 3D (samples, time_steps, features) for LSTM
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))

print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")


x_test, y_test = [], []

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])  # 60 previous time steps
    y_test.append(test_data[i, 0])  # The next value

# Convert x_test and y_test to numpy arrays
x_test, y_test = np.array(x_test), np.array(y_test)

# Reshape x_test to be 3D (samples, time_steps, features) for LSTM
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
#                      Date Type Symbol       Company Name   Volume  High Price  \
# 0     2015-Feb-2015-02-02  REG  'SYS'  'Systems Limited'  'READY'     42.0000
# 1     2015-Feb-2015-02-03  REG  'SYS'  'Systems Limited'  'READY'     44.0857
# 2     2015-Feb-2015-02-04  REG  'SYS'  'Systems Limited'  'READY'     46.2800
# 3     2015-Feb-2015-02-06  REG  'SYS'  'Systems Limited'  'READY'     48.5940
# 4     2015-Feb-2015-02-09  REG  'SYS'  'Systems Limited'  'READY'     51.0195
# ...                   ...  ...    ...                ...      ...         ...
# 2180  2023-Dec-2023-12-22  REG  'SYS'  'Systems Limited'  'READY'    454.0200
# 2181  2023-Dec-2023-12-26  REG  'SYS'  'Systems Limited'  'READY'    445.7700
# 2182  2023-Dec-2023-12-27  REG  'SYS'  'Systems Limited'  'READY'    464.8000
# 2183  2023-Dec-2023-12-28  REG  'SYS'  'Systems Limited'  'READY'    456.9300
# 2184  2023-Dec-2023-12-29  REG  'SYS'  'Systems Limited'  'READY'    455.3300
#
#       Low Price  Closing Price
# 0       38.0000        40.0000
# 1       39.8871        41.9864
# 2       41.8724        44.0762
# 3       43.9660        46.2800
# 4       46.1605        48.5900
# ...         ...            ...
# 2180   390.6600       422.3400
# 2181   383.5700       414.6700
# 2182   399.9400       432.3700
# 2183   393.1700       425.0500
# 2184   391.7900       423.5600
#
# [2185 rows x 8 columns]
# Training Data Length:  2076
# x_train shape: (2016, 60, 1)
# y_train shape: (2016,)
# x_test shape: (109, 60, 1)
# y_test shape: (109,)

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(256, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Reduce learning rate on plateau
lr_scheduler = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, min_lr=0.0001)

# Train the model
model.fit(x_train, y_train, batch_size=64, epochs=1000, callbacks=[lr_scheduler], workers=8, use_multiprocessing=True)
# Out:
# 2024-11-22 20:23:34.578339: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-11-22 20:23:34.578403: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-11-22 20:23:34.578419: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-11-22 20:23:34.578554: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-11-22 20:23:34.578595: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/1000
# 2024-11-22 20:23:37.586152: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-11-22 20:23:37.859085: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-11-22 20:23:38.709136: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-11-22 20:23:38.932001: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-11-22 20:23:40.655746: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-11-22 20:23:41.487592: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-11-22 20:23:41.798418: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 32/32 [==============================] - 9s 89ms/step - loss: 0.0175 - lr: 0.0010
# Epoch 2/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 0.0023 - lr: 0.0010
# Epoch 3/1000
# 32/32 [==============================] - 2s 63ms/step - loss: 0.0018 - lr: 0.0010
# Epoch 4/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 0.0019 - lr: 0.0010
# Epoch 5/1000
# 32/32 [==============================] - 2s 68ms/step - loss: 0.0017 - lr: 0.0010
# Epoch 6/1000
# 32/32 [==============================] - 2s 67ms/step - loss: 0.0015 - lr: 0.0010
# Epoch 7/1000
# 32/32 [==============================] - 2s 68ms/step - loss: 0.0012 - lr: 0.0010
# Epoch 8/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 0.0014 - lr: 0.0010
# Epoch 9/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 0.0013 - lr: 0.0010
# Epoch 10/1000
# 32/32 [==============================] - 2s 64ms/step - loss: 0.0012 - lr: 0.0010
# Epoch 11/1000
# 32/32 [==============================] - 2s 63ms/step - loss: 0.0010 - lr: 0.0010
# Epoch 12/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 0.0010 - lr: 0.0010
# Epoch 13/1000
# 32/32 [==============================] - 2s 69ms/step - loss: 9.4171e-04 - lr: 0.0010
# Epoch 14/1000
# 32/32 [==============================] - 2s 67ms/step - loss: 9.0730e-04 - lr: 0.0010
# Epoch 15/1000
# 32/32 [==============================] - 2s 67ms/step - loss: 9.5138e-04 - lr: 0.0010
# Epoch 16/1000
# 32/32 [==============================] - 2s 69ms/step - loss: 8.6126e-04 - lr: 0.0010
# Epoch 17/1000
# 32/32 [==============================] - 2s 71ms/step - loss: 8.5451e-04 - lr: 0.0010
# Epoch 18/1000
# 32/32 [==============================] - 2s 65ms/step - loss: 7.3167e-04 - lr: 0.0010
# Epoch 19/1000
# 32/32 [==============================] - 2s 65ms/step - loss: 0.0010 - lr: 0.0010
# Epoch 20/1000
# 32/32 [==============================] - 2s 69ms/step - loss: 7.2141e-04 - lr: 0.0010
# Epoch 21/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 5.9480e-04 - lr: 0.0010
# Epoch 22/1000
# 32/32 [==============================] - 2s 71ms/step - loss: 6.0494e-04 - lr: 0.0010
# Epoch 23/1000
# 32/32 [==============================] - 2s 65ms/step - loss: 6.0750e-04 - lr: 0.0010
# Epoch 24/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 6.0021e-04 - lr: 0.0010
# Epoch 25/1000
# 32/32 [==============================] - 2s 65ms/step - loss: 5.4372e-04 - lr: 0.0010
# Epoch 26/1000
# 32/32 [==============================] - 2s 67ms/step - loss: 5.2093e-04 - lr: 0.0010
# Epoch 27/1000
# 32/32 [==============================] - 2s 63ms/step - loss: 5.2408e-04 - lr: 5.0000e-04
# Epoch 28/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 5.2949e-04 - lr: 5.0000e-04
# Epoch 29/1000
# 32/32 [==============================] - 2s 68ms/step - loss: 4.8462e-04 - lr: 5.0000e-04
# Epoch 30/1000
# 32/32 [==============================] - 2s 65ms/step - loss: 4.7693e-04 - lr: 5.0000e-04
# Epoch 31/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 5.0386e-04 - lr: 5.0000e-04
# Epoch 32/1000
# 32/32 [==============================] - 2s 62ms/step - loss: 4.6822e-04 - lr: 5.0000e-04
# Epoch 33/1000
# 32/32 [==============================] - 2s 63ms/step - loss: 5.2092e-04 - lr: 5.0000e-04
# Epoch 34/1000
# 32/32 [==============================] - 2s 64ms/step - loss: 4.3500e-04 - lr: 5.0000e-04
# Epoch 35/1000
# 32/32 [==============================] - 2s 63ms/step - loss: 4.6886e-04 - lr: 2.5000e-04
# Epoch 36/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 4.7334e-04 - lr: 2.5000e-04
# Epoch 37/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 4.6064e-04 - lr: 2.5000e-04
# Epoch 38/1000
# 32/32 [==============================] - 2s 67ms/step - loss: 4.6978e-04 - lr: 2.5000e-04
# Epoch 39/1000
# 32/32 [==============================] - 2s 63ms/step - loss: 4.3323e-04 - lr: 2.5000e-04
# Epoch 40/1000
# 32/32 [==============================] - 2s 63ms/step - loss: 4.2410e-04 - lr: 1.2500e-04
# Epoch 41/1000
# 32/32 [==============================] - 2s 65ms/step - loss: 4.5902e-04 - lr: 1.2500e-04
# Epoch 42/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 4.1861e-04 - lr: 1.2500e-04
# Epoch 43/1000
# 32/32 [==============================] - 2s 68ms/step - loss: 4.2056e-04 - lr: 1.2500e-04
# Epoch 44/1000
# 32/32 [==============================] - 2s 65ms/step - loss: 4.2678e-04 - lr: 1.2500e-04
# Epoch 45/1000
# 32/32 [==============================] - 2s 62ms/step - loss: 4.1591e-04 - lr: 1.0000e-04
# Epoch 46/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 4.1458e-04 - lr: 1.0000e-04
# Epoch 47/1000
# 32/32 [==============================] - 2s 65ms/step - loss: 3.9786e-04 - lr: 1.0000e-04
# Epoch 48/1000
# 32/32 [==============================] - 2s 68ms/step - loss: 4.2491e-04 - lr: 1.0000e-04
# Epoch 49/1000
# 32/32 [==============================] - 2s 65ms/step - loss: 4.0629e-04 - lr: 1.0000e-04
# Epoch 50/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 4.1846e-04 - lr: 1.0000e-04
# Epoch 51/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 4.3310e-04 - lr: 1.0000e-04
# Epoch 52/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 4.0217e-04 - lr: 1.0000e-04
# Epoch 53/1000
# 32/32 [==============================] - 2s 63ms/step - loss: 4.1007e-04 - lr: 1.0000e-04
# Epoch 54/1000
# 32/32 [==============================] - 2s 71ms/step - loss: 3.9829e-04 - lr: 1.0000e-04
# Epoch 55/1000
# 32/32 [==============================] - 2s 70ms/step - loss: 4.0954e-04 - lr: 1.0000e-04
# Epoch 56/1000
# 32/32 [==============================] - 2s 65ms/step - loss: 4.2232e-04 - lr: 1.0000e-04
# Epoch 57/1000
# 32/32 [==============================] - 2s 69ms/step - loss: 4.0417e-04 - lr: 1.0000e-04
# Epoch 58/1000
# 32/32 [==============================] - 2s 68ms/step - loss: 4.0330e-04 - lr: 1.0000e-04
# Epoch 59/1000
# 32/32 [==============================] - 2s 70ms/step - loss: 4.0338e-04 - lr: 1.0000e-04
# Epoch 60/1000
# 32/32 [==============================] - 2s 73ms/step - loss: 4.0511e-04 - lr: 1.0000e-04
# Epoch 61/1000
# 32/32 [==============================] - 2s 70ms/step - loss: 3.9175e-04 - lr: 1.0000e-04
# Epoch 62/1000
# 32/32 [==============================] - 2s 69ms/step - loss: 3.9692e-04 - lr: 1.0000e-04
# Epoch 63/1000
# 32/32 [==============================] - 2s 70ms/step - loss: 4.0446e-04 - lr: 1.0000e-04
# Epoch 64/1000
# 32/32 [==============================] - 2s 66ms/step - loss: 3.8792e-04 - lr: 1.0000e-04
# Epoch 65/1000
# 32/32 [==============================] - 2s 71ms/step - loss: 4.2457e-04 - lr: 1.0000e-04
# Epoch 66/1000
# 32/32 [==============================] - 2s 71ms/step - loss: 3.8566e-04 - lr: 1.0000e-04
# Epoch 67/1000
# 32/32 [==============================] - 2s 71ms/step - loss: 3.9139e-04 - lr: 1.0000e-04
# Epoch 68/1000
# 32/32 [==============================] - 2s 74ms/step - loss: 4.0397e-04 - lr: 1.0000e-04
# Epoch 69/1000
# 32/32 [==============================] - 2s 70ms/step - loss: 4.3326e-04 - lr: 1.0000e-04
# Epoch 70/1000
# 32/32 [==============================] - 2s 69ms/step - loss: 4.0838e-04 - lr: 1.0000e-04
# Epoch 71/1000
# 32/32 [==============================] - 2s 68ms/step - loss: 3.9559e-04 - lr: 1.0000e-04
# Epoch 72/1000
# 32/32 [==============================] - 2s 74ms/step - loss: 4.0977e-04 - lr: 1.0000e-04
# Epoch 73/1000
# 32/32 [==============================] - 2s 71ms/step - loss: 4.1023e-04 - lr: 1.0000e-04
# Epoch 74/1000
# 32/32 [==============================] - 2s 70ms/step - loss: 4.0841e-04 - lr: 1.0000e-04
# Epoch 75/1000
# 32/32 [==============================] - 2s 72ms/step - loss: 4.0586e-04 - lr: 1.0000e-04
# Epoch 76/1000
# 32/32 [==============================] - 2s 73ms/step - loss: 3.8230e-04 - lr: 1.0000e-04
# Epoch 77/1000
# 32/32 [==============================] - 2s 71ms/step - loss: 3.9510e-04 - lr: 1.0000e-04
# Epoch 78/1000
# 32/32 [==============================] - 2s 74ms/step - loss: 3.8083e-04 - lr: 1.0000e-04
# Epoch 79/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 3.7269e-04 - lr: 1.0000e-04
# Epoch 80/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 3.9014e-04 - lr: 1.0000e-04
# Epoch 81/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 3.8526e-04 - lr: 1.0000e-04
# Epoch 82/1000
# 32/32 [==============================] - 2s 71ms/step - loss: 3.9963e-04 - lr: 1.0000e-04
# Epoch 83/1000
# 32/32 [==============================] - 2s 73ms/step - loss: 3.9867e-04 - lr: 1.0000e-04
# Epoch 84/1000
# 32/32 [==============================] - 2s 73ms/step - loss: 3.9790e-04 - lr: 1.0000e-04
# Epoch 85/1000
# 32/32 [==============================] - 2s 74ms/step - loss: 4.0985e-04 - lr: 1.0000e-04
# Epoch 86/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 3.7882e-04 - lr: 1.0000e-04
# Epoch 87/1000
# 32/32 [==============================] - 2s 74ms/step - loss: 3.6935e-04 - lr: 1.0000e-04
# Epoch 88/1000
# 32/32 [==============================] - 2s 74ms/step - loss: 3.8454e-04 - lr: 1.0000e-04
# Epoch 89/1000
# 32/32 [==============================] - 2s 74ms/step - loss: 3.9551e-04 - lr: 1.0000e-04
# Epoch 90/1000
# 32/32 [==============================] - 2s 74ms/step - loss: 4.0016e-04 - lr: 1.0000e-04
# Epoch 91/1000
# 32/32 [==============================] - 2s 69ms/step - loss: 3.6377e-04 - lr: 1.0000e-04
# Epoch 92/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 3.8890e-04 - lr: 1.0000e-04
# Epoch 93/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 4.1181e-04 - lr: 1.0000e-04
# Epoch 94/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 4.0106e-04 - lr: 1.0000e-04
# Epoch 95/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 4.4405e-04 - lr: 1.0000e-04
# Epoch 96/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 3.7616e-04 - lr: 1.0000e-04
# Epoch 97/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 3.8636e-04 - lr: 1.0000e-04
# Epoch 98/1000
# 32/32 [==============================] - 2s 73ms/step - loss: 3.7120e-04 - lr: 1.0000e-04
# Epoch 99/1000
# 32/32 [==============================] - 2s 73ms/step - loss: 3.7441e-04 - lr: 1.0000e-04
# Epoch 100/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.8423e-04 - lr: 1.0000e-04
# Epoch 101/1000
# 32/32 [==============================] - 2s 78ms/step - loss: 3.8255e-04 - lr: 1.0000e-04
# Epoch 102/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 3.8666e-04 - lr: 1.0000e-04
# Epoch 103/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 3.7350e-04 - lr: 1.0000e-04
# Epoch 104/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 3.7218e-04 - lr: 1.0000e-04
# Epoch 105/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 4.0959e-04 - lr: 1.0000e-04
# Epoch 106/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 3.8488e-04 - lr: 1.0000e-04
# Epoch 107/1000
# 32/32 [==============================] - 2s 73ms/step - loss: 3.7534e-04 - lr: 1.0000e-04
# Epoch 108/1000
# 32/32 [==============================] - 2s 74ms/step - loss: 3.5861e-04 - lr: 1.0000e-04
# Epoch 109/1000
# 32/32 [==============================] - 2s 74ms/step - loss: 3.7118e-04 - lr: 1.0000e-04
# Epoch 110/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 3.8549e-04 - lr: 1.0000e-04
# Epoch 111/1000
# 32/32 [==============================] - 2s 74ms/step - loss: 3.8510e-04 - lr: 1.0000e-04
# Epoch 112/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.4358e-04 - lr: 1.0000e-04
# Epoch 113/1000
# 32/32 [==============================] - 2s 74ms/step - loss: 3.7808e-04 - lr: 1.0000e-04
# Epoch 114/1000
# 32/32 [==============================] - 2s 74ms/step - loss: 3.7036e-04 - lr: 1.0000e-04
# Epoch 115/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 3.7151e-04 - lr: 1.0000e-04
# Epoch 116/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 3.5295e-04 - lr: 1.0000e-04
# Epoch 117/1000
# 32/32 [==============================] - 2s 78ms/step - loss: 3.5520e-04 - lr: 1.0000e-04
# Epoch 118/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.7800e-04 - lr: 1.0000e-04
# Epoch 119/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 3.5175e-04 - lr: 1.0000e-04
# Epoch 120/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.7454e-04 - lr: 1.0000e-04
# Epoch 121/1000
# 32/32 [==============================] - 2s 74ms/step - loss: 3.6023e-04 - lr: 1.0000e-04
# Epoch 122/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 3.6814e-04 - lr: 1.0000e-04
# Epoch 123/1000
# 32/32 [==============================] - 2s 78ms/step - loss: 3.5238e-04 - lr: 1.0000e-04
# Epoch 124/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 3.6803e-04 - lr: 1.0000e-04
# Epoch 125/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 3.4506e-04 - lr: 1.0000e-04
# Epoch 126/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 3.6093e-04 - lr: 1.0000e-04
# Epoch 127/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 3.6105e-04 - lr: 1.0000e-04
# Epoch 128/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.5687e-04 - lr: 1.0000e-04
# Epoch 129/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 3.4901e-04 - lr: 1.0000e-04
# Epoch 130/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 3.4631e-04 - lr: 1.0000e-04
# Epoch 131/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 3.4350e-04 - lr: 1.0000e-04
# Epoch 132/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 3.6060e-04 - lr: 1.0000e-04
# Epoch 133/1000
# 32/32 [==============================] - 2s 78ms/step - loss: 3.4841e-04 - lr: 1.0000e-04
# Epoch 134/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 3.6404e-04 - lr: 1.0000e-04
# Epoch 135/1000
# 32/32 [==============================] - 2s 78ms/step - loss: 3.5665e-04 - lr: 1.0000e-04
# Epoch 136/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.5280e-04 - lr: 1.0000e-04
# Epoch 137/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.5306e-04 - lr: 1.0000e-04
# Epoch 138/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 3.6471e-04 - lr: 1.0000e-04
# Epoch 139/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 3.5812e-04 - lr: 1.0000e-04
# Epoch 140/1000
# 32/32 [==============================] - 3s 78ms/step - loss: 3.4852e-04 - lr: 1.0000e-04
# Epoch 141/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 3.3572e-04 - lr: 1.0000e-04
# Epoch 142/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 3.3871e-04 - lr: 1.0000e-04
# Epoch 143/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.5529e-04 - lr: 1.0000e-04
# Epoch 144/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 3.5297e-04 - lr: 1.0000e-04
# Epoch 145/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 3.2645e-04 - lr: 1.0000e-04
# Epoch 146/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 3.3801e-04 - lr: 1.0000e-04
# Epoch 147/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.3150e-04 - lr: 1.0000e-04
# Epoch 148/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.4067e-04 - lr: 1.0000e-04
# Epoch 149/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.2506e-04 - lr: 1.0000e-04
# Epoch 150/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 3.5590e-04 - lr: 1.0000e-04
# Epoch 151/1000
# 32/32 [==============================] - 3s 78ms/step - loss: 3.4598e-04 - lr: 1.0000e-04
# Epoch 152/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 3.4766e-04 - lr: 1.0000e-04
# Epoch 153/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 3.2545e-04 - lr: 1.0000e-04
# Epoch 154/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 3.2534e-04 - lr: 1.0000e-04
# Epoch 155/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 3.3178e-04 - lr: 1.0000e-04
# Epoch 156/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 3.4764e-04 - lr: 1.0000e-04
# Epoch 157/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 3.2642e-04 - lr: 1.0000e-04
# Epoch 158/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 3.1689e-04 - lr: 1.0000e-04
# Epoch 159/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 3.3659e-04 - lr: 1.0000e-04
# Epoch 160/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 3.2792e-04 - lr: 1.0000e-04
# Epoch 161/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 3.2862e-04 - lr: 1.0000e-04
# Epoch 162/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 3.2408e-04 - lr: 1.0000e-04
# Epoch 163/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 3.2588e-04 - lr: 1.0000e-04
# Epoch 164/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.2991e-04 - lr: 1.0000e-04
# Epoch 165/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 3.3154e-04 - lr: 1.0000e-04
# Epoch 166/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 3.2497e-04 - lr: 1.0000e-04
# Epoch 167/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 3.2076e-04 - lr: 1.0000e-04
# Epoch 168/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.1372e-04 - lr: 1.0000e-04
# Epoch 169/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 3.5261e-04 - lr: 1.0000e-04
# Epoch 170/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 3.4887e-04 - lr: 1.0000e-04
# Epoch 171/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 3.0850e-04 - lr: 1.0000e-04
# Epoch 172/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 3.2629e-04 - lr: 1.0000e-04
# Epoch 173/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.1024e-04 - lr: 1.0000e-04
# Epoch 174/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 3.2705e-04 - lr: 1.0000e-04
# Epoch 175/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 3.0707e-04 - lr: 1.0000e-04
# Epoch 176/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 3.6350e-04 - lr: 1.0000e-04
# Epoch 177/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.9284e-04 - lr: 1.0000e-04
# Epoch 178/1000
# 32/32 [==============================] - 3s 78ms/step - loss: 3.0978e-04 - lr: 1.0000e-04
# Epoch 179/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 3.1233e-04 - lr: 1.0000e-04
# Epoch 180/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 3.2171e-04 - lr: 1.0000e-04
# Epoch 181/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.1970e-04 - lr: 1.0000e-04
# Epoch 182/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 3.2398e-04 - lr: 1.0000e-04
# Epoch 183/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 3.4207e-04 - lr: 1.0000e-04
# Epoch 184/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 3.1816e-04 - lr: 1.0000e-04
# Epoch 185/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 3.1227e-04 - lr: 1.0000e-04
# Epoch 186/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.9066e-04 - lr: 1.0000e-04
# Epoch 187/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.9614e-04 - lr: 1.0000e-04
# Epoch 188/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 3.0114e-04 - lr: 1.0000e-04
# Epoch 189/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 3.3508e-04 - lr: 1.0000e-04
# Epoch 190/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.9998e-04 - lr: 1.0000e-04
# Epoch 191/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.9114e-04 - lr: 1.0000e-04
# Epoch 192/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 3.3038e-04 - lr: 1.0000e-04
# Epoch 193/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.8163e-04 - lr: 1.0000e-04
# Epoch 194/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.9704e-04 - lr: 1.0000e-04
# Epoch 195/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.8475e-04 - lr: 1.0000e-04
# Epoch 196/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.8294e-04 - lr: 1.0000e-04
# Epoch 197/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.8832e-04 - lr: 1.0000e-04
# Epoch 198/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.8408e-04 - lr: 1.0000e-04
# Epoch 199/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 3.0843e-04 - lr: 1.0000e-04
# Epoch 200/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.8371e-04 - lr: 1.0000e-04
# Epoch 201/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.8063e-04 - lr: 1.0000e-04
# Epoch 202/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 3.1763e-04 - lr: 1.0000e-04
# Epoch 203/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 3.0055e-04 - lr: 1.0000e-04
# Epoch 204/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.9460e-04 - lr: 1.0000e-04
# Epoch 205/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.7613e-04 - lr: 1.0000e-04
# Epoch 206/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.8801e-04 - lr: 1.0000e-04
# Epoch 207/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.6488e-04 - lr: 1.0000e-04
# Epoch 208/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.9052e-04 - lr: 1.0000e-04
# Epoch 209/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.7854e-04 - lr: 1.0000e-04
# Epoch 210/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.9170e-04 - lr: 1.0000e-04
# Epoch 211/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.8044e-04 - lr: 1.0000e-04
# Epoch 212/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.8786e-04 - lr: 1.0000e-04
# Epoch 213/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.9270e-04 - lr: 1.0000e-04
# Epoch 214/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.8924e-04 - lr: 1.0000e-04
# Epoch 215/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 2.6805e-04 - lr: 1.0000e-04
# Epoch 216/1000
# 32/32 [==============================] - 2s 78ms/step - loss: 3.1902e-04 - lr: 1.0000e-04
# Epoch 217/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.9313e-04 - lr: 1.0000e-04
# Epoch 218/1000
# 32/32 [==============================] - 3s 78ms/step - loss: 3.0662e-04 - lr: 1.0000e-04
# Epoch 219/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.7125e-04 - lr: 1.0000e-04
# Epoch 220/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.7815e-04 - lr: 1.0000e-04
# Epoch 221/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.8614e-04 - lr: 1.0000e-04
# Epoch 222/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.9489e-04 - lr: 1.0000e-04
# Epoch 223/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.7475e-04 - lr: 1.0000e-04
# Epoch 224/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.6524e-04 - lr: 1.0000e-04
# Epoch 225/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.7934e-04 - lr: 1.0000e-04
# Epoch 226/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.8967e-04 - lr: 1.0000e-04
# Epoch 227/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.6904e-04 - lr: 1.0000e-04
# Epoch 228/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.5945e-04 - lr: 1.0000e-04
# Epoch 229/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.9494e-04 - lr: 1.0000e-04
# Epoch 230/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 2.7531e-04 - lr: 1.0000e-04
# Epoch 231/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.7510e-04 - lr: 1.0000e-04
# Epoch 232/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.6513e-04 - lr: 1.0000e-04
# Epoch 233/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.6573e-04 - lr: 1.0000e-04
# Epoch 234/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.8084e-04 - lr: 1.0000e-04
# Epoch 235/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.7236e-04 - lr: 1.0000e-04
# Epoch 236/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.5692e-04 - lr: 1.0000e-04
# Epoch 237/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.5950e-04 - lr: 1.0000e-04
# Epoch 238/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.6004e-04 - lr: 1.0000e-04
# Epoch 239/1000
# 32/32 [==============================] - 3s 78ms/step - loss: 2.7038e-04 - lr: 1.0000e-04
# Epoch 240/1000
# 32/32 [==============================] - 3s 78ms/step - loss: 2.8177e-04 - lr: 1.0000e-04
# Epoch 241/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.4488e-04 - lr: 1.0000e-04
# Epoch 242/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.5352e-04 - lr: 1.0000e-04
# Epoch 243/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 2.7143e-04 - lr: 1.0000e-04
# Epoch 244/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 2.7488e-04 - lr: 1.0000e-04
# Epoch 245/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.5635e-04 - lr: 1.0000e-04
# Epoch 246/1000
# 32/32 [==============================] - 2s 78ms/step - loss: 2.5846e-04 - lr: 1.0000e-04
# Epoch 247/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.6221e-04 - lr: 1.0000e-04
# Epoch 248/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.9797e-04 - lr: 1.0000e-04
# Epoch 249/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.9514e-04 - lr: 1.0000e-04
# Epoch 250/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.8101e-04 - lr: 1.0000e-04
# Epoch 251/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.4630e-04 - lr: 1.0000e-04
# Epoch 252/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 2.5195e-04 - lr: 1.0000e-04
# Epoch 253/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.5927e-04 - lr: 1.0000e-04
# Epoch 254/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.4187e-04 - lr: 1.0000e-04
# Epoch 255/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.5779e-04 - lr: 1.0000e-04
# Epoch 256/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.5298e-04 - lr: 1.0000e-04
# Epoch 257/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.6908e-04 - lr: 1.0000e-04
# Epoch 258/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.3081e-04 - lr: 1.0000e-04
# Epoch 259/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.5143e-04 - lr: 1.0000e-04
# Epoch 260/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.4461e-04 - lr: 1.0000e-04
# Epoch 261/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.5344e-04 - lr: 1.0000e-04
# Epoch 262/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.7115e-04 - lr: 1.0000e-04
# Epoch 263/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.4600e-04 - lr: 1.0000e-04
# Epoch 264/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 2.7493e-04 - lr: 1.0000e-04
# Epoch 265/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.5459e-04 - lr: 1.0000e-04
# Epoch 266/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 2.5343e-04 - lr: 1.0000e-04
# Epoch 267/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.6319e-04 - lr: 1.0000e-04
# Epoch 268/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.5630e-04 - lr: 1.0000e-04
# Epoch 269/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.4857e-04 - lr: 1.0000e-04
# Epoch 270/1000
# 32/32 [==============================] - 3s 78ms/step - loss: 2.5893e-04 - lr: 1.0000e-04
# Epoch 271/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.4161e-04 - lr: 1.0000e-04
# Epoch 272/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 2.6836e-04 - lr: 1.0000e-04
# Epoch 273/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 2.4878e-04 - lr: 1.0000e-04
# Epoch 274/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.4964e-04 - lr: 1.0000e-04
# Epoch 275/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.6568e-04 - lr: 1.0000e-04
# Epoch 276/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 2.3694e-04 - lr: 1.0000e-04
# Epoch 277/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.4445e-04 - lr: 1.0000e-04
# Epoch 278/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.6379e-04 - lr: 1.0000e-04
# Epoch 279/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.4336e-04 - lr: 1.0000e-04
# Epoch 280/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 2.3617e-04 - lr: 1.0000e-04
# Epoch 281/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 2.3556e-04 - lr: 1.0000e-04
# Epoch 282/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.4158e-04 - lr: 1.0000e-04
# Epoch 283/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.6141e-04 - lr: 1.0000e-04
# Epoch 284/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.5493e-04 - lr: 1.0000e-04
# Epoch 285/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.3249e-04 - lr: 1.0000e-04
# Epoch 286/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.3601e-04 - lr: 1.0000e-04
# Epoch 287/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.3307e-04 - lr: 1.0000e-04
# Epoch 288/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.6202e-04 - lr: 1.0000e-04
# Epoch 289/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.2242e-04 - lr: 1.0000e-04
# Epoch 290/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.4095e-04 - lr: 1.0000e-04
# Epoch 291/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.5550e-04 - lr: 1.0000e-04
# Epoch 292/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.4825e-04 - lr: 1.0000e-04
# Epoch 293/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.2717e-04 - lr: 1.0000e-04
# Epoch 294/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.6590e-04 - lr: 1.0000e-04
# Epoch 295/1000
# 32/32 [==============================] - 2s 78ms/step - loss: 2.4005e-04 - lr: 1.0000e-04
# Epoch 296/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.4879e-04 - lr: 1.0000e-04
# Epoch 297/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.4385e-04 - lr: 1.0000e-04
# Epoch 298/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 2.4549e-04 - lr: 1.0000e-04
# Epoch 299/1000
# 32/32 [==============================] - 2s 76ms/step - loss: 2.3676e-04 - lr: 1.0000e-04
# Epoch 300/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.3932e-04 - lr: 1.0000e-04
# Epoch 301/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.5054e-04 - lr: 1.0000e-04
# Epoch 302/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.3614e-04 - lr: 1.0000e-04
# Epoch 303/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.4893e-04 - lr: 1.0000e-04
# Epoch 304/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.2412e-04 - lr: 1.0000e-04
# Epoch 305/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.3445e-04 - lr: 1.0000e-04
# Epoch 306/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.2474e-04 - lr: 1.0000e-04
# Epoch 307/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.4198e-04 - lr: 1.0000e-04
# Epoch 308/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.2716e-04 - lr: 1.0000e-04
# Epoch 309/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.5344e-04 - lr: 1.0000e-04
# Epoch 310/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.5641e-04 - lr: 1.0000e-04
# Epoch 311/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.2304e-04 - lr: 1.0000e-04
# Epoch 312/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.5325e-04 - lr: 1.0000e-04
# Epoch 313/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.2097e-04 - lr: 1.0000e-04
# Epoch 314/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.5589e-04 - lr: 1.0000e-04
# Epoch 315/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.4084e-04 - lr: 1.0000e-04
# Epoch 316/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.3100e-04 - lr: 1.0000e-04
# Epoch 317/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.3694e-04 - lr: 1.0000e-04
# Epoch 318/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.4189e-04 - lr: 1.0000e-04
# Epoch 319/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.3005e-04 - lr: 1.0000e-04
# Epoch 320/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.2057e-04 - lr: 1.0000e-04
# Epoch 321/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.3591e-04 - lr: 1.0000e-04
# Epoch 322/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.5375e-04 - lr: 1.0000e-04
# Epoch 323/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.2269e-04 - lr: 1.0000e-04
# Epoch 324/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.4155e-04 - lr: 1.0000e-04
# Epoch 325/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.2096e-04 - lr: 1.0000e-04
# Epoch 326/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.4510e-04 - lr: 1.0000e-04
# Epoch 327/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 2.3385e-04 - lr: 1.0000e-04
# Epoch 328/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.3452e-04 - lr: 1.0000e-04
# Epoch 329/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.2822e-04 - lr: 1.0000e-04
# Epoch 330/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.6872e-04 - lr: 1.0000e-04
# Epoch 331/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.3384e-04 - lr: 1.0000e-04
# Epoch 332/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 2.2359e-04 - lr: 1.0000e-04
# Epoch 333/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.3645e-04 - lr: 1.0000e-04
# Epoch 334/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.1816e-04 - lr: 1.0000e-04
# Epoch 335/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.3139e-04 - lr: 1.0000e-04
# Epoch 336/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.3320e-04 - lr: 1.0000e-04
# Epoch 337/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.5019e-04 - lr: 1.0000e-04
# Epoch 338/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.2509e-04 - lr: 1.0000e-04
# Epoch 339/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.2892e-04 - lr: 1.0000e-04
# Epoch 340/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.3341e-04 - lr: 1.0000e-04
# Epoch 341/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.3633e-04 - lr: 1.0000e-04
# Epoch 342/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.3520e-04 - lr: 1.0000e-04
# Epoch 343/1000
# 32/32 [==============================] - 2s 75ms/step - loss: 2.3976e-04 - lr: 1.0000e-04
# Epoch 344/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.3806e-04 - lr: 1.0000e-04
# Epoch 345/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.2599e-04 - lr: 1.0000e-04
# Epoch 346/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.3967e-04 - lr: 1.0000e-04
# Epoch 347/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.2219e-04 - lr: 1.0000e-04
# Epoch 348/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.4115e-04 - lr: 1.0000e-04
# Epoch 349/1000
# 32/32 [==============================] - 2s 77ms/step - loss: 2.2551e-04 - lr: 1.0000e-04
# Epoch 350/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.2153e-04 - lr: 1.0000e-04
# Epoch 351/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.4810e-04 - lr: 1.0000e-04
# Epoch 352/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.2904e-04 - lr: 1.0000e-04
# Epoch 353/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.2451e-04 - lr: 1.0000e-04
# Epoch 354/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.4264e-04 - lr: 1.0000e-04
# Epoch 355/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.3821e-04 - lr: 1.0000e-04
# Epoch 356/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.2540e-04 - lr: 1.0000e-04
# Epoch 357/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.3780e-04 - lr: 1.0000e-04
# Epoch 358/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.1637e-04 - lr: 1.0000e-04
# Epoch 359/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.1676e-04 - lr: 1.0000e-04
# Epoch 360/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.4289e-04 - lr: 1.0000e-04
# Epoch 361/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.3490e-04 - lr: 1.0000e-04
# Epoch 362/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.2859e-04 - lr: 1.0000e-04
# Epoch 363/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.2044e-04 - lr: 1.0000e-04
# Epoch 364/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.1470e-04 - lr: 1.0000e-04
# Epoch 365/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.3436e-04 - lr: 1.0000e-04
# Epoch 366/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.2155e-04 - lr: 1.0000e-04
# Epoch 367/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.4509e-04 - lr: 1.0000e-04
# Epoch 368/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.2196e-04 - lr: 1.0000e-04
# Epoch 369/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.2975e-04 - lr: 1.0000e-04
# Epoch 370/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.2799e-04 - lr: 1.0000e-04
# Epoch 371/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 1.9779e-04 - lr: 1.0000e-04
# Epoch 372/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.4895e-04 - lr: 1.0000e-04
# Epoch 373/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.3730e-04 - lr: 1.0000e-04
# Epoch 374/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.2634e-04 - lr: 1.0000e-04
# Epoch 375/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.2250e-04 - lr: 1.0000e-04
# Epoch 376/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.1319e-04 - lr: 1.0000e-04
# Epoch 377/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.3724e-04 - lr: 1.0000e-04
# Epoch 378/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.1383e-04 - lr: 1.0000e-04
# Epoch 379/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.2326e-04 - lr: 1.0000e-04
# Epoch 380/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.2994e-04 - lr: 1.0000e-04
# Epoch 381/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.6977e-04 - lr: 1.0000e-04
# Epoch 382/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.1136e-04 - lr: 1.0000e-04
# Epoch 383/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 2.2547e-04 - lr: 1.0000e-04
# Epoch 384/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.1937e-04 - lr: 1.0000e-04
# Epoch 385/1000
# 32/32 [==============================] - 3s 91ms/step - loss: 2.2710e-04 - lr: 1.0000e-04
# Epoch 386/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.2130e-04 - lr: 1.0000e-04
# Epoch 387/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.2532e-04 - lr: 1.0000e-04
# Epoch 388/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.1225e-04 - lr: 1.0000e-04
# Epoch 389/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.2460e-04 - lr: 1.0000e-04
# Epoch 390/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.3543e-04 - lr: 1.0000e-04
# Epoch 391/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.1129e-04 - lr: 1.0000e-04
# Epoch 392/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.2667e-04 - lr: 1.0000e-04
# Epoch 393/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.2826e-04 - lr: 1.0000e-04
# Epoch 394/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.1869e-04 - lr: 1.0000e-04
# Epoch 395/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.2068e-04 - lr: 1.0000e-04
# Epoch 396/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.2998e-04 - lr: 1.0000e-04
# Epoch 397/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.2358e-04 - lr: 1.0000e-04
# Epoch 398/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.2341e-04 - lr: 1.0000e-04
# Epoch 399/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.2619e-04 - lr: 1.0000e-04
# Epoch 400/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.2128e-04 - lr: 1.0000e-04
# Epoch 401/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.4114e-04 - lr: 1.0000e-04
# Epoch 402/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.3048e-04 - lr: 1.0000e-04
# Epoch 403/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.1714e-04 - lr: 1.0000e-04
# Epoch 404/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.0751e-04 - lr: 1.0000e-04
# Epoch 405/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.2050e-04 - lr: 1.0000e-04
# Epoch 406/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.2379e-04 - lr: 1.0000e-04
# Epoch 407/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.1863e-04 - lr: 1.0000e-04
# Epoch 408/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.3056e-04 - lr: 1.0000e-04
# Epoch 409/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.1968e-04 - lr: 1.0000e-04
# Epoch 410/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.1727e-04 - lr: 1.0000e-04
# Epoch 411/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.4106e-04 - lr: 1.0000e-04
# Epoch 412/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.2333e-04 - lr: 1.0000e-04
# Epoch 413/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.1889e-04 - lr: 1.0000e-04
# Epoch 414/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.1189e-04 - lr: 1.0000e-04
# Epoch 415/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.1351e-04 - lr: 1.0000e-04
# Epoch 416/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.0931e-04 - lr: 1.0000e-04
# Epoch 417/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.2979e-04 - lr: 1.0000e-04
# Epoch 418/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.1701e-04 - lr: 1.0000e-04
# Epoch 419/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.3275e-04 - lr: 1.0000e-04
# Epoch 420/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.2122e-04 - lr: 1.0000e-04
# Epoch 421/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.2653e-04 - lr: 1.0000e-04
# Epoch 422/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.1076e-04 - lr: 1.0000e-04
# Epoch 423/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.5923e-04 - lr: 1.0000e-04
# Epoch 424/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.3478e-04 - lr: 1.0000e-04
# Epoch 425/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.1292e-04 - lr: 1.0000e-04
# Epoch 426/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.2258e-04 - lr: 1.0000e-04
# Epoch 427/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 2.3257e-04 - lr: 1.0000e-04
# Epoch 428/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.1798e-04 - lr: 1.0000e-04
# Epoch 429/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.1399e-04 - lr: 1.0000e-04
# Epoch 430/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.2287e-04 - lr: 1.0000e-04
# Epoch 431/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 2.2422e-04 - lr: 1.0000e-04
# Epoch 432/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.0350e-04 - lr: 1.0000e-04
# Epoch 433/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.2090e-04 - lr: 1.0000e-04
# Epoch 434/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.3678e-04 - lr: 1.0000e-04
# Epoch 435/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.1922e-04 - lr: 1.0000e-04
# Epoch 436/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.2485e-04 - lr: 1.0000e-04
# Epoch 437/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.2834e-04 - lr: 1.0000e-04
# Epoch 438/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.3623e-04 - lr: 1.0000e-04
# Epoch 439/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 2.1343e-04 - lr: 1.0000e-04
# Epoch 440/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 2.3843e-04 - lr: 1.0000e-04
# Epoch 441/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.2748e-04 - lr: 1.0000e-04
# Epoch 442/1000
# ...
# Epoch 847/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 2.0784e-04 - lr: 1.0000e-04
# Epoch 848/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.1342e-04 - lr: 1.0000e-04
# Epoch 849/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 1.9562e-04 - lr: 1.0000e-04
# Epoch 850/1000
# 32/32 [==============================] - 3s 80ms/step - loss: 1.9997e-04 - lr: 1.0000e-04
# Epoch 851/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 2.0688e-04 - lr: 1.0000e-04
# Epoch 852/1000
# 32/32 [==============================] - 3s 90ms/step - loss: 2.0296e-04 - lr: 1.0000e-04
# Epoch 853/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 2.0812e-04 - lr: 1.0000e-04
# Epoch 854/1000
# 32/32 [==============================] - 3s 91ms/step - loss: 1.9643e-04 - lr: 1.0000e-04
# Epoch 855/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 1.9823e-04 - lr: 1.0000e-04
# Epoch 856/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.0105e-04 - lr: 1.0000e-04
# Epoch 857/1000
# 32/32 [==============================] - 3s 90ms/step - loss: 2.1297e-04 - lr: 1.0000e-04
# Epoch 858/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 1.9710e-04 - lr: 1.0000e-04
# Epoch 859/1000
# 32/32 [==============================] - 3s 93ms/step - loss: 2.0567e-04 - lr: 1.0000e-04
# Epoch 860/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 1.9456e-04 - lr: 1.0000e-04
# Epoch 861/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 1.9474e-04 - lr: 1.0000e-04
# Epoch 862/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 2.0267e-04 - lr: 1.0000e-04
# Epoch 863/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.0211e-04 - lr: 1.0000e-04
# Epoch 864/1000
# 32/32 [==============================] - 3s 91ms/step - loss: 2.1823e-04 - lr: 1.0000e-04
# Epoch 865/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 1.9139e-04 - lr: 1.0000e-04
# Epoch 866/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 1.9974e-04 - lr: 1.0000e-04
# Epoch 867/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 1.9445e-04 - lr: 1.0000e-04
# Epoch 868/1000
# 32/32 [==============================] - 3s 79ms/step - loss: 2.0471e-04 - lr: 1.0000e-04
# Epoch 869/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 1.9246e-04 - lr: 1.0000e-04
# Epoch 870/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 1.9162e-04 - lr: 1.0000e-04
# Epoch 871/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.0588e-04 - lr: 1.0000e-04
# Epoch 872/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 1.9834e-04 - lr: 1.0000e-04
# Epoch 873/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.0592e-04 - lr: 1.0000e-04
# Epoch 874/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 2.0298e-04 - lr: 1.0000e-04
# Epoch 875/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 1.9974e-04 - lr: 1.0000e-04
# Epoch 876/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.0858e-04 - lr: 1.0000e-04
# Epoch 877/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.0464e-04 - lr: 1.0000e-04
# Epoch 878/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 1.8591e-04 - lr: 1.0000e-04
# Epoch 879/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 2.0782e-04 - lr: 1.0000e-04
# Epoch 880/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.0120e-04 - lr: 1.0000e-04
# Epoch 881/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.1501e-04 - lr: 1.0000e-04
# Epoch 882/1000
# 32/32 [==============================] - 3s 90ms/step - loss: 2.1206e-04 - lr: 1.0000e-04
# Epoch 883/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.0036e-04 - lr: 1.0000e-04
# Epoch 884/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 1.9617e-04 - lr: 1.0000e-04
# Epoch 885/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 1.9303e-04 - lr: 1.0000e-04
# Epoch 886/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.0496e-04 - lr: 1.0000e-04
# Epoch 887/1000
# 32/32 [==============================] - 3s 92ms/step - loss: 1.9853e-04 - lr: 1.0000e-04
# Epoch 888/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.1237e-04 - lr: 1.0000e-04
# Epoch 889/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 2.0843e-04 - lr: 1.0000e-04
# Epoch 890/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 2.2221e-04 - lr: 1.0000e-04
# Epoch 891/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 1.9507e-04 - lr: 1.0000e-04
# Epoch 892/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 1.9458e-04 - lr: 1.0000e-04
# Epoch 893/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 1.9810e-04 - lr: 1.0000e-04
# Epoch 894/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 1.9580e-04 - lr: 1.0000e-04
# Epoch 895/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 2.0114e-04 - lr: 1.0000e-04
# Epoch 896/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 2.0723e-04 - lr: 1.0000e-04
# Epoch 897/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 1.9994e-04 - lr: 1.0000e-04
# Epoch 898/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 1.9597e-04 - lr: 1.0000e-04
# Epoch 899/1000
# 32/32 [==============================] - 3s 93ms/step - loss: 2.0532e-04 - lr: 1.0000e-04
# Epoch 900/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 1.9918e-04 - lr: 1.0000e-04
# Epoch 901/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 2.0650e-04 - lr: 1.0000e-04
# Epoch 902/1000
# 32/32 [==============================] - 3s 91ms/step - loss: 2.0014e-04 - lr: 1.0000e-04
# Epoch 903/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 2.0389e-04 - lr: 1.0000e-04
# Epoch 904/1000
# 32/32 [==============================] - 3s 96ms/step - loss: 2.0877e-04 - lr: 1.0000e-04
# Epoch 905/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 1.9749e-04 - lr: 1.0000e-04
# Epoch 906/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.1560e-04 - lr: 1.0000e-04
# Epoch 907/1000
# 32/32 [==============================] - 3s 96ms/step - loss: 1.9495e-04 - lr: 1.0000e-04
# Epoch 908/1000
# 32/32 [==============================] - 3s 90ms/step - loss: 2.0411e-04 - lr: 1.0000e-04
# Epoch 909/1000
# 32/32 [==============================] - 3s 91ms/step - loss: 1.9298e-04 - lr: 1.0000e-04
# Epoch 910/1000
# 32/32 [==============================] - 3s 81ms/step - loss: 2.0481e-04 - lr: 1.0000e-04
# Epoch 911/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 1.9246e-04 - lr: 1.0000e-04
# Epoch 912/1000
# 32/32 [==============================] - 3s 94ms/step - loss: 2.0239e-04 - lr: 1.0000e-04
# Epoch 913/1000
# 32/32 [==============================] - 3s 90ms/step - loss: 2.0701e-04 - lr: 1.0000e-04
# Epoch 914/1000
# 32/32 [==============================] - 3s 91ms/step - loss: 2.0166e-04 - lr: 1.0000e-04
# Epoch 915/1000
# 32/32 [==============================] - 3s 90ms/step - loss: 1.9613e-04 - lr: 1.0000e-04
# Epoch 916/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 2.0369e-04 - lr: 1.0000e-04
# Epoch 917/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 1.9125e-04 - lr: 1.0000e-04
# Epoch 918/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 1.9641e-04 - lr: 1.0000e-04
# Epoch 919/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 1.9816e-04 - lr: 1.0000e-04
# Epoch 920/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 1.9661e-04 - lr: 1.0000e-04
# Epoch 921/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 1.9859e-04 - lr: 1.0000e-04
# Epoch 922/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 2.0379e-04 - lr: 1.0000e-04
# Epoch 923/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 1.8238e-04 - lr: 1.0000e-04
# Epoch 924/1000
# 32/32 [==============================] - 3s 93ms/step - loss: 1.9803e-04 - lr: 1.0000e-04
# Epoch 925/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 1.9971e-04 - lr: 1.0000e-04
# Epoch 926/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 1.9032e-04 - lr: 1.0000e-04
# Epoch 927/1000
# 32/32 [==============================] - 3s 92ms/step - loss: 1.7837e-04 - lr: 1.0000e-04
# Epoch 928/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 2.1284e-04 - lr: 1.0000e-04
# Epoch 929/1000
# 32/32 [==============================] - 3s 91ms/step - loss: 2.0617e-04 - lr: 1.0000e-04
# Epoch 930/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 1.9256e-04 - lr: 1.0000e-04
# Epoch 931/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 1.9823e-04 - lr: 1.0000e-04
# Epoch 932/1000
# 32/32 [==============================] - 3s 90ms/step - loss: 1.9582e-04 - lr: 1.0000e-04
# Epoch 933/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 2.0104e-04 - lr: 1.0000e-04
# Epoch 934/1000
# 32/32 [==============================] - 3s 93ms/step - loss: 1.9471e-04 - lr: 1.0000e-04
# Epoch 935/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 1.9873e-04 - lr: 1.0000e-04
# Epoch 936/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.3043e-04 - lr: 1.0000e-04
# Epoch 937/1000
# 32/32 [==============================] - 3s 94ms/step - loss: 2.2458e-04 - lr: 1.0000e-04
# Epoch 938/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.0400e-04 - lr: 1.0000e-04
# Epoch 939/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 1.9424e-04 - lr: 1.0000e-04
# Epoch 940/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.0576e-04 - lr: 1.0000e-04
# Epoch 941/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.0244e-04 - lr: 1.0000e-04
# Epoch 942/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 1.9815e-04 - lr: 1.0000e-04
# Epoch 943/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 1.9558e-04 - lr: 1.0000e-04
# Epoch 944/1000
# 32/32 [==============================] - 3s 90ms/step - loss: 1.9421e-04 - lr: 1.0000e-04
# Epoch 945/1000
# 32/32 [==============================] - 4s 127ms/step - loss: 1.9890e-04 - lr: 1.0000e-04
# Epoch 946/1000
# 32/32 [==============================] - 5s 130ms/step - loss: 1.9865e-04 - lr: 1.0000e-04
# Epoch 947/1000
# 32/32 [==============================] - 3s 90ms/step - loss: 1.9335e-04 - lr: 1.0000e-04
# Epoch 948/1000
# 32/32 [==============================] - 3s 96ms/step - loss: 2.0291e-04 - lr: 1.0000e-04
# Epoch 949/1000
# 32/32 [==============================] - 3s 104ms/step - loss: 1.9937e-04 - lr: 1.0000e-04
# Epoch 950/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 1.9064e-04 - lr: 1.0000e-04
# Epoch 951/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 1.9805e-04 - lr: 1.0000e-04
# Epoch 952/1000
# 32/32 [==============================] - 3s 93ms/step - loss: 2.0071e-04 - lr: 1.0000e-04
# Epoch 953/1000
# 32/32 [==============================] - 3s 96ms/step - loss: 2.1701e-04 - lr: 1.0000e-04
# Epoch 954/1000
# 32/32 [==============================] - 3s 95ms/step - loss: 1.9744e-04 - lr: 1.0000e-04
# Epoch 955/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 1.9762e-04 - lr: 1.0000e-04
# Epoch 956/1000
# 32/32 [==============================] - 3s 91ms/step - loss: 1.9570e-04 - lr: 1.0000e-04
# Epoch 957/1000
# 32/32 [==============================] - 3s 98ms/step - loss: 2.1274e-04 - lr: 1.0000e-04
# Epoch 958/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.0077e-04 - lr: 1.0000e-04
# Epoch 959/1000
# 32/32 [==============================] - 3s 93ms/step - loss: 2.0760e-04 - lr: 1.0000e-04
# Epoch 960/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.0096e-04 - lr: 1.0000e-04
# Epoch 961/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 1.8311e-04 - lr: 1.0000e-04
# Epoch 962/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 1.9583e-04 - lr: 1.0000e-04
# Epoch 963/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 2.1683e-04 - lr: 1.0000e-04
# Epoch 964/1000
# 32/32 [==============================] - 3s 92ms/step - loss: 2.0154e-04 - lr: 1.0000e-04
# Epoch 965/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 1.9653e-04 - lr: 1.0000e-04
# Epoch 966/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.1164e-04 - lr: 1.0000e-04
# Epoch 967/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 1.9749e-04 - lr: 1.0000e-04
# Epoch 968/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 1.9596e-04 - lr: 1.0000e-04
# Epoch 969/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 1.9415e-04 - lr: 1.0000e-04
# Epoch 970/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 1.9984e-04 - lr: 1.0000e-04
# Epoch 971/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 1.9262e-04 - lr: 1.0000e-04
# Epoch 972/1000
# 32/32 [==============================] - 3s 91ms/step - loss: 2.0693e-04 - lr: 1.0000e-04
# Epoch 973/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 2.0854e-04 - lr: 1.0000e-04
# Epoch 974/1000
# 32/32 [==============================] - 3s 85ms/step - loss: 1.9743e-04 - lr: 1.0000e-04
# Epoch 975/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 1.9124e-04 - lr: 1.0000e-04
# Epoch 976/1000
# 32/32 [==============================] - 3s 96ms/step - loss: 1.9538e-04 - lr: 1.0000e-04
# Epoch 977/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 1.9098e-04 - lr: 1.0000e-04
# Epoch 978/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 1.9746e-04 - lr: 1.0000e-04
# Epoch 979/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 2.0213e-04 - lr: 1.0000e-04
# Epoch 980/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 1.9362e-04 - lr: 1.0000e-04
# Epoch 981/1000
# 32/32 [==============================] - 3s 90ms/step - loss: 1.8753e-04 - lr: 1.0000e-04
# Epoch 982/1000
# 32/32 [==============================] - 3s 88ms/step - loss: 1.9716e-04 - lr: 1.0000e-04
# Epoch 983/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 1.9210e-04 - lr: 1.0000e-04
# Epoch 984/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 1.9855e-04 - lr: 1.0000e-04
# Epoch 985/1000
# 32/32 [==============================] - 3s 86ms/step - loss: 2.0301e-04 - lr: 1.0000e-04
# Epoch 986/1000
# 32/32 [==============================] - 3s 92ms/step - loss: 1.9867e-04 - lr: 1.0000e-04
# Epoch 987/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 1.9079e-04 - lr: 1.0000e-04
# Epoch 988/1000
# 32/32 [==============================] - 3s 90ms/step - loss: 1.9702e-04 - lr: 1.0000e-04
# Epoch 989/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 2.0047e-04 - lr: 1.0000e-04
# Epoch 990/1000
# 32/32 [==============================] - 3s 87ms/step - loss: 1.9016e-04 - lr: 1.0000e-04
# Epoch 991/1000
# 32/32 [==============================] - 3s 82ms/step - loss: 1.9834e-04 - lr: 1.0000e-04
# Epoch 992/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 1.9621e-04 - lr: 1.0000e-04
# Epoch 993/1000
# 32/32 [==============================] - 3s 90ms/step - loss: 1.8842e-04 - lr: 1.0000e-04
# Epoch 994/1000
# 32/32 [==============================] - 3s 84ms/step - loss: 1.9284e-04 - lr: 1.0000e-04
# Epoch 995/1000
# 32/32 [==============================] - 3s 90ms/step - loss: 1.8724e-04 - lr: 1.0000e-04
# Epoch 996/1000
# 32/32 [==============================] - 3s 83ms/step - loss: 1.9275e-04 - lr: 1.0000e-04
# Epoch 997/1000
# 32/32 [==============================] - 3s 89ms/step - loss: 2.0558e-04 - lr: 1.0000e-04
# Epoch 998/1000
#  8/32 [======>.......................] - ETA: 2s - loss: 1.2599e-04

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
y_test = y_test.reshape(-1, 1)  # Reshape for inverse_transform compatibility
y_test = scaler.inverse_transform(y_test)

# %%
# Create the 'valid' DataFrame with predictions
valid = df[training_data_len:].copy()  # Create a copy of the validation data
valid['Predictions'] = predictions  # Add predictions to 'valid'

# Plot the data
plt.figure(figsize=(16, 6))
plt.title('LSTM Model: Actual vs Predictions', fontsize=20)
plt.xlabel('Date', fontsize=16)
plt.ylabel('Close Price PKR (Rs.)', fontsize=16)

# Plot the training data, validation data, and predictions
plt.plot(df['Closing Price'][:training_data_len], label='Train Data', color='blue')  # Plot train data
plt.plot(valid['Closing Price'], label='Validation Data', color='green')  # Plot validation data
plt.plot(valid['Predictions'], label='Predictions', color='red', linestyle='--')  # Plot predictions

plt.legend(loc='upper left', fontsize=12)
plt.show()

# Display a portion of the 'valid' table for comparison
print(valid[['Closing Price', 'Predictions']].head(10))  # Show first 10 rows of 'valid'


# Calculate the percentage difference between actual and predicted values
valid['Difference'] = np.abs((valid['Closing Price'] - valid['Predictions']) / valid['Closing Price']) * 100

# Categorize predictions based on different percentage differences
valid['Prediction Correct ±1%'] = valid['Difference'] <= 1
valid['Prediction Correct ±2%'] = valid['Difference'] <= 2
valid['Prediction Correct ±5%'] = valid['Difference'] <= 5

# Calculate the total number of predictions, correct predictions, and incorrect predictions for each condition
total_predictions = len(valid)
correct_predictions_1 = valid['Prediction Correct ±1%'].sum()
correct_predictions_2 = valid['Prediction Correct ±2%'].sum()
correct_predictions_5 = valid['Prediction Correct ±5%'].sum()

incorrect_predictions_1 = total_predictions - correct_predictions_1
incorrect_predictions_2 = total_predictions - correct_predictions_2
incorrect_predictions_5 = total_predictions - correct_predictions_5

# Calculate accuracies for ±1%, ±2%, and ±5%
accuracy_1 = (correct_predictions_1 / total_predictions) * 100  # ±1% accuracy
accuracy_2 = (correct_predictions_2 / total_predictions) * 100  # ±2% accuracy
accuracy_5 = (correct_predictions_5 / total_predictions) * 100  # ±5% accuracy

# Output the results
print(f'Total Predictions: {total_predictions}')
# print(f'Correct Predictions ±1%: {correct_predictions_1} ({accuracy_1:.2f}%)')
# print(f'Correct Predictions ±2%: {correct_predictions_2} ({accuracy_2:.2f}%)')
print(f'Correct Predictions ±5%: {correct_predictions_5} ({accuracy_5:.2f}%)')

# Save the results to a CSV file
validity_filename = stock + '_valid_predictions.csv'
valid.to_csv(validity_filename, columns=['Closing Price', 'Predictions', 'Difference', 'Prediction Correct ±1%', 'Prediction Correct ±2%', 'Prediction Correct ±5%'])

# %%
rmse = np.sqrt(mean_squared_error(valid['Closing Price'], valid['Predictions']))
print(f"RMSE: {rmse}")

# %%
# Number of days/weeks/months you want to predict into the future
future_steps = 120  # Adjust as needed (e.g., 30 days into the future)

# Use the last 60 values from the training data to start the prediction
input_sequence = scaled_data[-60:]  # Use the last 60 scaled values
input_sequence = input_sequence.reshape((1, 60, 1))  # Reshape for LSTM input

# Prepare an empty list to store the future predictions
future_predictions = []

# Make future predictions iteratively
for _ in range(future_steps):
    # Predict the next value
    prediction = model.predict(input_sequence)
    
    # Append the prediction to the list of future predictions
    future_predictions.append(prediction[0][0])
    
    # Update the input sequence for the next prediction
    input_sequence = np.append(input_sequence[:, 1:, :], prediction.reshape(1, 1, 1), axis=1)

# Inverse scale the predictions to get the actual values
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# Generate a date range for the future predictions (adjust based on your data's frequency)
last_date = df.index[-1]  # Get the last date in the dataset
date_range = pd.date_range(last_date, periods=future_steps + 1, freq='D')[1:]  # Predict next `future_steps` days

# Create a DataFrame for the future predictions
future_df = pd.DataFrame(future_predictions, index=date_range, columns=['Predicted Close Price'])

# Display the future predictions
print(future_df)

# Plot the future predictions
plt.figure(figsize=(16, 6))
plt.title('Future Predictions vs Actual Data', fontsize=20)
plt.plot(df['Closing Price'], label='Actual Closing Price', color='blue')
plt.plot(future_df.index, future_df['Predicted Close Price'], label='Future Predictions', color='red')
plt.xlabel('Date', fontsize=16)
plt.ylabel('Close Price PKR (Rs.)', fontsize=16)
plt.legend(loc='upper left', fontsize=12)
plt.show()

# %%
model_name=stock + '_model.keras'
model.save(model_name)
